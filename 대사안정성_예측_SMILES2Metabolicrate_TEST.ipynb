# %%
# !pip install deepchem

# %%
import os
os.chdir('/content/drive/MyDrive/약물대사예측')

# %%
# %run Metabolism_only_smiles.py
# Out:
# WARNING:deepchem.models.torch_models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. No module named 'torch_geometric'
# WARNING:deepchem.models:Skipped loading modules with pytorch-geometric dependency, missing a dependency. cannot import name 'DMPNN' from 'deepchem.models.torch_models' (/usr/local/lib/python3.10/dist-packages/deepchem/models/torch_models/__init__.py)
# WARNING:deepchem.models:Skipped loading modules with pytorch-lightning dependency, missing a dependency. No module named 'pytorch_lightning'
# WARNING:deepchem.models:Skipped loading some Jax models, missing a dependency. No module named 'haiku'

# %%
test_file = pd.read_csv('/content/drive/MyDrive/약물대사예측/test.csv')
test_file = test_file.loc[:,'SMILES']
test_file = test_file.to_frame()

# %% [markdown]
# SMILES2Metabolicrate(file)

# %%
SMILES2Metabolicrate(test_file)
# Out:
# 16/16 [==============================] - 1s 41ms/step
#            MLM        HLM
# 0    34.680229  55.937583
# 1    54.762212  70.426412
# 2    35.902222  57.902885
# 3    34.909130  55.316668
# 4    45.002877  64.022086
# ..         ...        ...
# 478  22.514737  41.087802
# 479  66.729830  77.981089
# 480  43.190058  55.636464
# 481  57.604276  67.785243
# 482  24.738063  55.767407
#
# [483 rows x 2 columns]
